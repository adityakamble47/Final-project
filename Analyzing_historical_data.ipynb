# %%
import yfinance as yf
import pandas as pd

# %%
tesla_data = yf.download('TSLA', start='2020-01-01', end='2024-02-27')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesla_data.reset_index(inplace=True)

# %%
print(tesla_data.head())
# Out:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 1      2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2      2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 3      2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 4      2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
print(tesla_data)
# Out:
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   TSLA        TSLA        TSLA        TSLA       TSLA
# 0      2020-01-02   28.684000   28.713333   28.114000   28.299999  142981500
# 1      2020-01-03   29.534000   30.266666   29.128000   29.366667  266677500
# 2      2020-01-06   30.102667   30.104000   29.333332   29.364668  151995000
# 3      2020-01-07   31.270666   31.441999   30.224001   30.760000  268231500
# 4      2020-01-08   32.809334   33.232666   31.215334   31.580000  467164500
# ...           ...         ...         ...         ...         ...        ...
# 1039   2024-02-20  193.759995  198.600006  189.130005  196.130005  104545800
# 1040   2024-02-21  194.770004  199.440002  191.949997  193.360001  103844000
# 1041   2024-02-22  197.410004  198.320007  191.360001  194.000000   92739500
# 1042   2024-02-23  191.970001  197.570007  191.500000  195.309998   78841900
# ...

# %%
tesla_data.tail()
# Out:
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   TSLA        TSLA        TSLA        TSLA       TSLA
# 1039   2024-02-20  193.759995  198.600006  189.130005  196.130005  104545800
# 1040   2024-02-21  194.770004  199.440002  191.949997  193.360001  103844000
# 1041   2024-02-22  197.410004  198.320007  191.360001  194.000000   92739500
# 1042   2024-02-23  191.970001  197.570007  191.500000  195.309998   78841900
# 1043   2024-02-26  199.399994  201.779999  192.000000  192.289993  111747100

# %%
import pandas as pd
data = {'Date': ['2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01', '2024-05-01'],
        'Revenue': ['$20B', '$22B', '$21B', '$23B', '$25B']}

tesla_data = pd.DataFrame(data)
print(tesla_data.tail())
# Out:
#          Date Revenue
# 0  2024-01-01    $20B
# 1  2024-02-01    $22B
# 2  2024-03-01    $21B
# 3  2024-04-01    $23B
# 4  2024-05-01    $25B

# %%
gme_data = yf.download("GME", start="2023-01-01", end="2024-01-01")
gme_data.reset_index(inplace=True)
gme_data.to_csv("gme_stock_data.csv", index=False)

print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close       High        Low       Open   Volume
# Ticker                   GME        GME        GME        GME      GME
# 0      2023-01-03  17.200001  19.260000  17.090000  18.639999  5135200
# 1      2023-01-04  17.320000  17.930000  16.900000  17.250000  3939300
# 2      2023-01-05  16.219999  17.260000  15.890000  17.059999  6066200
# 3      2023-01-06  16.459999  16.570000  15.410000  16.000000  4823400
# 4      2023-01-09  16.379999  17.129999  16.360001  16.650000  3522600

# %%
import yfinance as yf
import pandas as pd

gme = yf.Ticker("GME")

gme_financials = gme.financials

gme_revenue = gme_financials.loc["Total Revenue"]

gme_revenue_df = pd.DataFrame(gme_revenue).reset_index()
gme_revenue_df.columns = ["Date", "Revenue"]

gme_revenue_df.to_csv("gme_revenue.csv", index=False)
print(gme_revenue_df.tail())
# Out:
#         Date       Revenue
# 0 2024-01-31  5272800000.0
# 1 2023-01-31  5927200000.0
# 2 2022-01-31  6010700000.0
# 3 2021-01-31  5089800000.0

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Function to plot stock data
def make_graph(stock_data, title="Stock Price Over Time"):
    plt.figure(figsize=(12, 6))
    plt.plot(stock_data['Date'], stock_data['Close'], label="Closing Price", color="blue")
    plt.xlabel("Date")
    plt.ylabel("Stock Price (USD)")
    plt.title(title)
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Fetch Tesla Stock Data
tesla_data = yf.download("TSLA", start="2023-01-01", end="2024-01-01")

# Reset index to use Date column properly
tesla_data.reset_index(inplace=True)

# Plot the Tesla stock data
make_graph(tesla_data, title="Tesla Stock Price (2023-2024)")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Function to plot stock data
def make_graph(stock_data, title="Stock Price Over Time"):
    plt.figure(figsize=(12, 6))
    plt.plot(stock_data['Date'], stock_data['Close'], label="Closing Price", color="red")
    plt.xlabel("Date")
    plt.ylabel("Stock Price (USD)")
    plt.title(title)
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Fetch GameStop Stock Data
gme_data = yf.download("GME", start="2023-01-01", end="2024-01-01")

# Reset index to use Date column properly
gme_data.reset_index(inplace=True)

# Plot the GameStop stock data
make_graph(gme_data, title="GameStop (GME) Stock Price (2023-2024)")
# Out:
# [*********************100%***********************]  1 of 1 completed
